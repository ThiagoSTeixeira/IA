# %% [markdown]
# # EP4 - Inteligência Artificial
# #### Thiago Santos Teixeira nUSP-10736987

# %% [markdown]
# ## Processamento de dados: Fleury-pacientes

# %%
import pandas as pd
pacientes = pd.read_csv('./dados/Grupo_Fleury_Dataset_Covid19_Pacientes.csv', sep = '|')
pacientes.shape
# Out:
# (129596, 7)

# %%
#Passo 1: Removendo eventuais duplicatas:
pacientes.drop_duplicates(keep = 'first', inplace = True)
pacientes.head()
# Out:
#                         ID_PACIENTE IC_SEXO AA_NASCIMENTO CD_PAIS CD_UF  \
# 0  1AD07C7A1E4D80B608DD7A650766CCF0       M          1961  Brasil    SP
# 1  7B10786D64F27D7732503D915A38DE6F       M          1945  Brasil    SP
# 2  83C018729869BB1BAB8819021D8E048E       F          1973  Brasil    SP
# 3  74F422BB575BF224F676EE88DD77301F       M          2000  Brasil    SP
# 4  3EDBAA8DBC42EE7F1CBBE2482B8CE42D       M          1972  Brasil    SP
#
#   CD_MUNICIPIO CD_CEP
# 0    SAO PAULO   CCCC
# 1    SAO PAULO   CCCC
# 2    SAO PAULO   CCCC
# 3    SAO PAULO   CCCC
# 4    SAO PAULO   CCCC

# %%
#Podemos notar que o dataset possue colunas inúteis ao nosso projeto, 
#como por exemplo a UF e o CEP, portanto, cortaremos elas.
pacientes = pacientes.drop("CD_UF", axis=1)
pacientes = pacientes.drop("CD_CEP", axis=1)
pacientes = pacientes.drop("CD_MUNICIPIO", axis =1)
pacientes.head()
# Out:
#                         ID_PACIENTE IC_SEXO AA_NASCIMENTO CD_PAIS
# 0  1AD07C7A1E4D80B608DD7A650766CCF0       M          1961  Brasil
# 1  7B10786D64F27D7732503D915A38DE6F       M          1945  Brasil
# 2  83C018729869BB1BAB8819021D8E048E       F          1973  Brasil
# 3  74F422BB575BF224F676EE88DD77301F       M          2000  Brasil
# 4  3EDBAA8DBC42EE7F1CBBE2482B8CE42D       M          1972  Brasil

# %%
#Para facilitar nossa implementação, trocaremos o valor do sexo do paciente de M e F para 0 e 1 respectivamente
pacientes['IC_SEXO'] = pacientes['IC_SEXO'].map( {'M': 0, 'F': 1} ).astype(int)

# %% [markdown]
# É possível perceber também que os valores contidos em "cd_pais" aparentam ser, em grande maioria, Brasil, portanto, checaremos quais alteracoes podemos ter nessa coluna:

# %%
pacientes['CD_PAIS'].unique() #devolvera todos os valores unicos da coluna
# Out:
# array(['Brasil'], dtype=object)

# %%
#Com a resposta da célula acima, podemos ter certeza de que só há um valor nessa coluna,
#e portanto ela também é descartável.
pacientes = pacientes.drop("CD_PAIS", axis = 1)
pacientes.head()
# Out:
#                         ID_PACIENTE  IC_SEXO AA_NASCIMENTO
# 0  1AD07C7A1E4D80B608DD7A650766CCF0        0          1961
# 1  7B10786D64F27D7732503D915A38DE6F        0          1945
# 2  83C018729869BB1BAB8819021D8E048E        1          1973
# 3  74F422BB575BF224F676EE88DD77301F        0          2000
# 4  3EDBAA8DBC42EE7F1CBBE2482B8CE42D        0          1972

# %%
pacientes.shape
# Out:
# (129596, 3)

# %% [markdown]
# Ah! Agora temos uma base de dados bem mais limpa e simples! Porém, ainda nos deparamos com um problema: algumas datas de nacimento estão com o valor "AAAA", ou seja, dados faltantes. Porém, como temos uma base de dados bastante extensa ainda (quase 130k linhas segundo a célula acima), podemos nos dar o luxo de eliminar pacientes sem DOB do dataset :)

# %%
pacientes = pacientes[pacientes.AA_NASCIMENTO != "AAAA"]

# %%
pacientes.head()
# Out:
#                         ID_PACIENTE  IC_SEXO AA_NASCIMENTO
# 0  1AD07C7A1E4D80B608DD7A650766CCF0        0          1961
# 1  7B10786D64F27D7732503D915A38DE6F        0          1945
# 2  83C018729869BB1BAB8819021D8E048E        1          1973
# 3  74F422BB575BF224F676EE88DD77301F        0          2000
# 4  3EDBAA8DBC42EE7F1CBBE2482B8CE42D        0          1972

# %% [markdown]
# Agora, para tornar os dados mais compreensívos antes de exportar para um novo csv, filtrarei o conteudo da data de nascimento para a idade do paciente, ou seja, para o valor `ano_atual - ano de nascimento`

# %%
def idade(DOB):
    return pd.Timestamp('now').year - int(DOB)
pacientes['IDADE'] = pacientes['AA_NASCIMENTO'].apply(idade)
pacientes = pacientes.drop("AA_NASCIMENTO", axis=1)
pacientes.head()
# Out:
#                         ID_PACIENTE  IC_SEXO  IDADE
# 0  1AD07C7A1E4D80B608DD7A650766CCF0        0     59
# 1  7B10786D64F27D7732503D915A38DE6F        0     75
# 2  83C018729869BB1BAB8819021D8E048E        1     47
# 3  74F422BB575BF224F676EE88DD77301F        0     20
# 4  3EDBAA8DBC42EE7F1CBBE2482B8CE42D        0     48

# %% [markdown]
# Exportando para um novo .csv:

# %%
pacientes.to_csv('./dados/Fpacientes_processado', header = True)

# %%
pacientes.shape
# Out:
# (128403, 3)

# %% [markdown]
# ## Processamento de dados: Fleury-exames

# %%
exames = pd.read_csv("./dados/Grupo_Fleury_Dataset_Covid19_Resultados_Exames.csv", sep = '|', encoding='latin-1')
exames.shape
# Out:
# (2496591, 8)

# %%
#Assim como fizemos com pacientes, removemos eventuais duplicatas:
exames.drop_duplicates(keep = 'first', inplace = True)
exames.shape
# Out:
# (2494613, 8)

# %%
exames.head()
# Out:
#                         ID_PACIENTE   DT_COLETA DE_ORIGEM  \
# 0  1AD07C7A1E4D80B608DD7A650766CCF0  19/03/2020       LAB
# 1  1AD07C7A1E4D80B608DD7A650766CCF0  19/03/2020       LAB
# 2  7B10786D64F27D7732503D915A38DE6F  30/12/2019       LAB
# 3  7B10786D64F27D7732503D915A38DE6F  30/12/2019       LAB
# 4  7B10786D64F27D7732503D915A38DE6F  30/12/2019       LAB
#
#                                             DE_EXAME  \
# 0  NOVO CORONAVÍRUS 2019 (SARS-CoV-2), DETECÇÃO P...
# 1  NOVO CORONAVÍRUS 2019 (SARS-CoV-2), DETECÇÃO P...
# 2                            HEMOGRAMA, sangue total
# 3                            HEMOGRAMA, sangue total
# 4                            HEMOGRAMA, sangue total
#
#                    DE_ANALITO            DE_RESULTADO CD_UNIDADE  \
# 0  Covid 19, Detecção por PCR           NÃO DETECTADO        NaN
# 1          Covid 19, Material  raspado de nasofaringe        NaN
# 2                 Hemoglobina                    15,2       g/dL
# 3                         VCM                    89,2         fL
# 4                  Leucócitos                    5940       /mm3
#
#   DE_VALOR_REFERENCIA
# 0       Não detectado
# 1                 NaN
# 2         13,5 a 17,5
# 3         81,0 a 95,0
# 4      3.500 a 10.500

# %% [markdown]
# Após retirarmos duplicatas, seguiremos a recomendação feita na aula e criaremos um novo dataset com a quantidade de cada tipo de exame que foi realizado, para isso, executaremos a célula abaixo.

# %%
exames_count = exames[['DE_EXAME', 'DE_ANALITO']].groupby(['DE_EXAME', 'DE_ANALITO'])['DE_ANALITO'] \
                                     .count().reset_index(name="COUNT").sort_values(["COUNT"], ascending=False)
exames_count
# Out:
#                                                DE_EXAME  \
# 277                       COVID19, ANTICORPOS IgG, soro
# 279                       COVID19, ANTICORPOS IgM, soro
# 278                       COVID19, ANTICORPOS IgG, soro
# 280                       COVID19, ANTICORPOS IgM, soro
# 797   NOVO CORONAVÍRUS 2019 (SARS-CoV-2), DETECÇÃO P...
# 798   NOVO CORONAVÍRUS 2019 (SARS-CoV-2), DETECÇÃO P...
# 542                             HEMOGRAMA, sangue total
# 550                             HEMOGRAMA, sangue total
# 521                             HEMOGRAMA, sangue total
# 524                             HEMOGRAMA, sangue total
# 529                             HEMOGRAMA, sangue total
# 526                             HEMOGRAMA, sangue total
# 528                             HEMOGRAMA, sangue total
# 541                             HEMOGRAMA, sangue total
# 540                             HEMOGRAMA, sangue total
# 537                             HEMOGRAMA, sangue total
# 527                             HEMOGRAMA, sangue total
# 530                             HEMOGRAMA, sangue total
# 536                             HEMOGRAMA, sangue total
# 531                             HEMOGRAMA, sangue total
# 517                             HEMOGRAMA, sangue total
# 518                             HEMOGRAMA, sangue total
# 523                             HEMOGRAMA, sangue total
# 522                             HEMOGRAMA, sangue total
# 539                             HEMOGRAMA, sangue total
# 538                             HEMOGRAMA, sangue total
# 547                             HEMOGRAMA, sangue total
# 551                             HEMOGRAMA, sangue total
# 290                                    CREATININA, soro
# 1138              TRANSAMINASE GLUTAMICO-PIRUVICA (TGP)
# ...                                                 ...
# 424                                       FERRO MEDULAR
# 95    ANTICORPOS ANTI-ANTIGENO PRECOCE DO VIRUS EB, ...
# 1174                                       URINA TIPO I
# 423                                       FERRO MEDULAR
# 300   CRYPTOCOCCUS NEOFORMANS, PESQUISA DE ANTICORPO...
# 272                                     CORTISONA, SORO
# 857   PESQUISA DE TOXOPLASMA GONDII POR MÉTODO MOLEC...
# 939               PROTROMBINA, TESTE DE MISTURA, plasma
# 851    PESQUISA DE MACROCREATINOQUINASE (MacroCK), soro
# 818                    PAINEL SOROLOGICO PARA ECHOVIRUS
# 261                             CORPOS CETONICOS, urina
# 1107  TESTE DE SUPRESSÃO DO CORTISOL, APÓS 2 MG DE D...
# 1108    TESTE DOS MULTIMEROS DO FATOR DE VON WILLEBRAND
# 262                                CORTICOSTERONA, soro
# 968             RUBEOLA, AVIDEZ DE ANTICORPOS IgG, soro
# 817                    PAINEL SOROLOGICO PARA ECHOVIRUS
# 1113  TESTE RÁPIDO PARA DETECÇÃO DE M. TUBERCULOSIS ...
# 816                    PAINEL SOROLOGICO PARA ECHOVIRUS
# 952   QUANTIFICAÇÃO DO TRANSCRITO DO REARRANJO PML/RARA
# 940               PROTROMBINA, TESTE DE MISTURA, plasma
# 1125                                TIROGLOBULINA, soro
# 950       QUANTIFICAÇÃO DA MUTAÇÃO p.V617F DO GENE JAK2
# 1127             TIROXINA (T4) LIVRE OBTIDA POR DIALISE
# 946       QUANTIFICACAO DE INIBIDOR DE FATOR IX, plasma
# 120   ANTICORPOS NEUTRALIZANTES CONTRA O VIRUS COXSA...
# 945       QUANTIFICACAO DE INIBIDOR DE FATOR IX, plasma
# 1141     TRIAGEM DE ANFETAMINAS E METANFETAMINAS, urina
# 759                               MAG, ANTICORPOS, soro
# 852                 PESQUISA DE MICROSPORIDIA NAS FEZES
# 731                         JO-1, AUTO-ANTICORPOS, soro
#
#                                          DE_ANALITO  COUNT
# 277   Covid 19, Anticorpos IgG, Quimiolumin.-Índice  84996
# 279   Covid 19, Anticorpos IgM, Quimiolumin.-Índice  84986
# 278   Covid 19, Anticorpos IgG, Quimioluminescência  83767
# 280   Covid 19, Anticorpos IgM, Quimioluminescência  83753
# 797                      Covid 19, Detecção por PCR  50223
# 798                              Covid 19, Material  50223
# 542                                       Plaquetas  35485
# 550                                             VCM  35485
# 521         Concentração de Hemoglobina Corpuscular  35485
# 524                                     Eritrócitos  35485
# 529                                      Leucócitos  35485
# 526                                     Hematócrito  35485
# 528                   Hemoglobina Corpuscular Média  35485
# 541                                 Neutrófilos (%)  35484
# 540                                     Neutrófilos  35484
# 537                                   Monócitos (%)  35484
# 527                                     Hemoglobina  35484
# 530                                      Linfócitos  35484
# 536                                       Monócitos  35484
# 531                                  Linfócitos (%)  35484
# 517                                       Basófilos  35483
# 518                                   Basófilos (%)  35483
# 523                                 Eosinófilos (%)  35483
# 522                                     Eosinófilos  35483
# 539                      Morfologia, Série Vermelha  35483
# 538                        Morfologia, Série Branca  35482
# 547                                             RDW  35480
# 551                        Volume plaquetário médio  34672
# 290                                      Creatinina  27184
# 1138                                      ALT (TGP)  25550
# ...                                             ...    ...
# 424                   Ferro medular - sideroblastos      1
# 95       Virus EB, anticorpos anti-antigeno precoce      1
# 1174                                Cristais, urina      1
# 423           Ferro medular - depósito intersticial      1
# 300                         Cryptococcus Neoformans      1
# 272                                 Cortisona, soro      1
# 857                           Toxoplasma Gondii DNA      1
# 939                                          TP/INR      1
# 851                            Macrocreatinoquinase      1
# 818                                Echovirus tipo 4      1
# 261                         Corpos cetônicos, urina      1
# 1107                     Cortisol após dexametasona      1
# 1108         Multímetros do fator de Von Willebrand      1
# 262                            Corticosterona, soro      1
# 968                             Rubeola, Avidez IgG      1
# 817                               Echovirus tipo 30      1
# 1113                                     Observação      1
# 816                               Echovirus tipo 11      1
# 952                          PML/RARA, translocação      1
# 940                            Tempo de Protrombina      1
# 1125                                     Observação      1
# 950            JAK2, Quantificação da mutação V617F      1
# 1127                    T4 Livre obtida por dialise      1
# 946                            Inibidor de Fator IX      1
# 120                                      Observação      1
# 945                             Dosagem de fator IX      1
# 1141            Anfetaminas e Metanfetaminas, urina      1
# 759                                 MAG, anticorpos      1
# 852                  Microsporidia, pesquisa, fezes      1
# 731      Jo-1, Auto-Anticorpos - imunodifusão dupla      1
#
# [1279 rows x 3 columns]

# %%
#salvando em csv:
exames_count.to_csv("./dados/exames_count.csv")
